# %%
#importing libraries

import random as rd
import hashlib
import phe
import rsa
import matplotlib.pyplot as plt
from timeit import default_timer as timer
import numpy as np

# %%
#declaring of varibles
numberOfExperts = 0
numberOfCandidates = 0
keySize = 0
#collection of homomophic public and private keys
dictionaryOfExpertPublicKeys = {}
dictionaryOfExpertPrivateKeys = {}

dictionaryOfCandidatesPublicKeys = {}
dictionaryOfCandidatesPrivateKeys = {}

publicKeyEmployer,privateKeyEmployer = 0,0


#Collection of rsa public and private keys for digital signature
dictOfrsaPubKey = {}
dictOfrsaPriKey = {}
marksToCandidates = []

# %%
def initVariables(E,C,key):
    global numberOfExperts, numberOfCandidates, keySize
    numberOfExperts, numberOfCandidates, keySize = E, C, key

# %%
#code to generate rsa public and private keys
def generateRSAKeys():
    global dictOfrsaPubKey, dicOfrsaPriKey
    for i in range(numberOfExperts):
        (pubkey, privkey) = rsa.newkeys(512)
        dictOfrsaPubKey[i],dictOfrsaPriKey[i] = pubkey, privkey

# %%
#this part of the code create the public and private homomorphic key pairs
def generateHomomorphickeyPairs():
    global publicKeyEmployer,privateKeyEmployer
    publicKeyEmployer,privateKeyEmployer = phe.generate_paillier_keypair(n_length= keySize)
    for i in range(numberOfExperts):
        x,y = phe.generate_paillier_keypair(n_length= keySize)
        dictionaryOfExpertPublicKeys[i] = x
        dictionaryOfExpertPrivateKeys[i] = y
        
    for i in range(numberOfCandidates):
        x,y = phe.generate_paillier_keypair(n_length= keySize)
        dictionaryOfCandidatesPublicKeys[i]= x
        dictionaryOfCandidatesPrivateKeys[i] = y

# %%
# function to create digital signature
def createDigitalSignature(message,i):
    privkey = dictOfrsaPriKey[i]
    temp = str(message).encode()
    signature = rsa.sign(temp, privkey, 'SHA-1')
    return signature

# %%
# tjhis part of the code works as the employer of the seconde frame work who finds the est candidate
def employerFindingBestCandidate(array):
    array = [privateKeyEmployer.raw_decrypt(x) for x in array]
    print(array.index(max(array)))
    print(array)

# %%
# this part of the code works as the candidate manager who adds the marks by multiplication of the encrytpion and than passes them to the employer
def candidateManagerFrameWork2BestCandidate():
    array  = []
    for i in range(len(marksToCandidates[0])):
        sum = 1
        for j in range(len(marksToCandidates)):
            sum = sum * marksToCandidates[j][i][0]
        array.append(sum)
    return array

# %%
def expertFunctionToGiveMarks():
    global marksToCandidates
    marksToCandidates = [[0 for i in range(numberOfCandidates)] for j in range(numberOfExperts)]
    start = timer()
    #this part of code simulates the expert giving marks to the candidates and storing them in form of matrix
    for i in range(numberOfExperts):
        for j in range(numberOfCandidates):
            mark = rd.randint(0,10)
            encryptedMark = publicKeyEmployer.raw_encrypt(mark)
            marksToCandidates[i][j] = [encryptedMark,createDigitalSignature(encryptedMark,i)]
    end = timer()
    return(end - start)

# %%
def runSimulation(experts,candidates,flag,keySize):
    experts = experts
    timeList = []
    candidates = candidates
    totalTime = 0
    if flag == "candidates":
        for i in range(len(candidates)):
            start = timer()
            initVariables(experts,candidates[i],keySize)
            generateHomomorphickeyPairs()
            generateRSAKeys()
            end = timer()
            t1 = end - start
            t2 = expertFunctionToGiveMarks()
            start = timer()
            candidateManagerFrameWork2BestCandidate()
            end = timer()
            t3 = end - start
            totalTime = t1 + (t2/experts) + t3
            timeList.append(totalTime)
    else: 
        for i in range(len(experts)):
            start = timer()
            initVariables(experts[i],candidates,keySize)
            generateHomomorphickeyPairs()
            generateRSAKeys()
            end = timer()
            t1 =end -start
            t2 = expertFunctionToGiveMarks()
            start = timer()
            candidateManagerFrameWork2BestCandidate()
            end = timer()
            t3 = end - start
            totalTime = t1 + (t2/ experts[i]) + t3
            timeList.append(totalTime)
    # print(timeList)
    return (timeList)

# %%
#this part of the code run the simulation for defined number of times and helps us to calcuate average execution time
def averageTimeConsumedFunction(experts, candidates,flag,keySize):
    timeMatrix = []
    for i in range(0,4):
        timeList= runSimulation(experts, candidates,flag,keySize)
        timeMatrix.append(timeList)
    # print(timeMatrix)        
    arr = np.array(timeMatrix, dtype='float32')
    # print(arr)
    columns_average = arr.mean(axis=0)

    if flag == "candidates":
        plt.title("Number of experts " + str(experts) + " and key size of " + str(keySize))
        plt.xlabel("Number Of Candidates")
        plt.ylabel("Average Execution Time(seconds)")   
        plt.bar(candidates, columns_average)
        plt.show()
        print(columns_average)
    else :
        plt.title("Number of candidates = " + str(candidates) + " and key size of " + str(keySize))
        plt.xlabel("Number Of Experts")
        plt.ylabel("Average Execution Time(seconds)")   
        plt.bar(experts, columns_average)
        plt.show()
        print(columns_average)

    
    return columns_average

# %%
def simulationHavingExpertsConstCandidatesVariable(experts, candidates,flag,keySize):
    column_average = averageTimeConsumedFunction(experts,candidates,flag,keySize)
    return column_average

# %%
def simulationHavingExpertsvariableCandidatesConst(experts,candidates,flag,keySize):
    column_average = averageTimeConsumedFunction(experts,candidates,flag,keySize)
    return column_average

# %%
keys = [128,256,512]
F2Time = []
for i in range(0,3):
    time = simulationHavingExpertsvariableCandidatesConst([2,4,6,8,10],20,"experts",keys[i])
    F2Time.append(time)
# Out:
# [0.07085956 0.1657783  0.2052812  0.22856091 0.3216948 ]
# [0.15350169 0.20912287 0.2677203  0.31864315 0.45548192]
# [0.40532938 0.52551776 0.6031999  0.68855983 0.69587165]

# %%
# %store F2Time
# Out:
# Stored 'F2Time' (list)

# %%
keys = [128,256,512]
F2TimeCandidateVariable = []
for i in range(0,3):
    time = simulationHavingExpertsConstCandidatesVariable(5,[10,20,30,40,50],"candidates",keys[i])
    F2TimeCandidateVariable.append(time)
# %store F2TimeCandidateVariable
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jb\Desktop\paper work 24nov\FrameWork2.ipynb Cell 16 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> F2TimeCandidateVariable = []
#       <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> for i in range(0,3):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a>     time = simulationHavingExpertsConstCandidatesVariable(5,[10,20,30,40,50],"candidates",keys[i])
#       <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a>     F2TimeCandidateVariable.append(time)
#       <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a> get_ipython().run_line_magic('store', 'F2TimeCandidateVariable')
#
# c:\Users\jb\Desktop\paper work 24nov\FrameWork2.ipynb Cell 16 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> def simulationHavingExpertsConstCandidatesVariable(experts, candidates,flag,keySize):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a>     column_average = averageTimeConsumedFunction(experts,candidates,flag,keySize)
#       <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a>     return column_average
#
# c:\Users\jb\Desktop\paper work 24nov\FrameWork2.ipynb Cell 16 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> timeMatrix = []
#       <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> for i in range(0,4):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a>     timeList= runSimulation(experts, candidates,flag,keySize)
#       <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a>     timeMatrix.append(timeList)
#       <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=6'>7</a> # print(timeMatrix)
#
# c:\Users\jb\Desktop\paper work 24nov\FrameWork2.ipynb Cell 16 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=11'>12</a> end = timer()
#      <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=12'>13</a> t1 = end - start
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=13'>14</a> t2 = expertFunctionToGiveMarks()
#      <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=14'>15</a> start = timer()
#      <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=15'>16</a> candidateManagerFrameWork2BestCandidate()
#
# c:\Users\jb\Desktop\paper work 24nov\FrameWork2.ipynb Cell 16 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a>         mark = rd.randint(0,10)
#       <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=8'>9</a>         encryptedMark = publicKeyEmployer.raw_encrypt(mark)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a>         marksToCandidates[i][j] = [encryptedMark,createDigitalSignature(encryptedMark,i)]
#      <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=10'>11</a> end = timer()
#      <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=11'>12</a> return(end - start)
#
# c:\Users\jb\Desktop\paper work 24nov\FrameWork2.ipynb Cell 16 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> privkey = dictOfrsaPriKey[i]
#       <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> temp = str(message).encode()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a> signature = rsa.sign(temp, privkey, 'SHA-1')
#       <a href='vscode-notebook-cell:/c%3A/Users/jb/Desktop/paper%20work%2024nov/FrameWork2.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a> return signature
#
# File c:\Users\jb\AppData\Local\Programs\Python\Python312\Lib\site-packages\rsa\pkcs1.py:339, in sign(message, priv_key, hash_method)
#     321 """Signs the message with the private key.
#     322
#     323 Hashes the message, then signs the hash with the given key. This is known
#    (...)
#     335
#     336 """
#     338 msg_hash = compute_hash(message, hash_method)
# --> 339 return sign_hash(msg_hash, priv_key, hash_method)
#
# File c:\Users\jb\AppData\Local\Programs\Python\Python312\Lib\site-packages\rsa\pkcs1.py:314, in sign_hash(hash_value, priv_key, hash_method)
#     311 padded = _pad_for_signing(cleartext, keylength)
#     313 payload = transform.bytes2int(padded)
# --> 314 encrypted = priv_key.blinded_encrypt(payload)
#     315 block = transform.int2bytes(encrypted, keylength)
#     317 return block
#
# File c:\Users\jb\AppData\Local\Programs\Python\Python312\Lib\site-packages\rsa\key.py:501, in PrivateKey.blinded_encrypt(self, message)
#     499 blinded, blindfac_inverse = self.blind(message)
#     500 encrypted = rsa.core.encrypt_int(blinded, self.d, self.n)
# --> 501 return self.unblind(encrypted, blindfac_inverse)
#
# File c:\Users\jb\AppData\Local\Programs\Python\Python312\Lib\site-packages\rsa\key.py:173, in AbstractKey.unblind(self, blinded, blindfac_inverse)
#     170     blinded = (message * pow(blindfac, self.e, self.n)) % self.n
#     171     return blinded, blindfac_inverse
# --> 173 def unblind(self, blinded: int, blindfac_inverse: int) -> int:
#     174     """Performs blinding on the message using random number 'blindfac_inverse'.
#     175
#     176     :param blinded: the blinded message, as integer, to unblind.
#    (...)
#     182     See https://en.wikipedia.org/wiki/Blinding_%28cryptography%29
#     183     """
#     184     return (blindfac_inverse * blinded) % self.n
#
# KeyboardInterrupt:
